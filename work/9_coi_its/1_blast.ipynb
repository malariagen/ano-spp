# %% [markdown]
# Blast COI and ITS2 sequences against nt and interpret results within a range of sequence similarity - 98% identical or higher for ITS2, 96% for COI.
#
# Use 7_species_id conda environment

# %%
from Bio.Blast import NCBIXML
from Bio import AlignIO, SeqIO
import os
import pandas as pd
from collections import defaultdict

# %%
# in
WD = '../../../data/phylo_ampl_dada2/coi_its2/work/'
FA = os.path.join(WD, 'seqman_fa/plate{}.fas')
XML = os.path.join(WD, 'blast_xml/plate{}.xml')
AMPSEQ_PRED = '../7_species_id/data/4_spp_predictions.csv'
SAMPLE_META = '../7_species_id/data/1_sample_seq.csv'
BOLD_TSV = os.path.join(WD, 'bold/bold_plate{}.tsv') # generated from BOLD_SEQ, see below

# out
BOLD_SEQ = os.path.join(WD, 'bold/bold_plate{}.fas')
OD = 'data'
SPP_PREDS = os.path.join(OD, 'species_predictions.csv')

# within-species parameters
COI_WITHINSP_IDENTITY = 0.96
ITS2_WITHINSP_IDENTITY = 0.98
MIN_WITHINSP_ALIGNED = 0.75

# %%
# !mkdir -p {OD}

# %% [markdown]
# ## Sequence for BOLD
#
# Need to reverse complement. Storing plates separately, as combined submission (127 sequences) raises error.
#
# Upon creation, each fasta file contents are pasted into BOLD identification interface at http://www.boldsystems.org/index.php/IDS_OpenIdEngine. Note that you need to be signed in to submit multiple sequences at once. Resulting files have xls extension, but those are plain text TSVs.

# %%
# bseq = []
for p in [1,2]:
    bseq = list(SeqIO.parse(FA.format(p),format='fasta'))
    for seq in bseq:
        seq.seq = seq.seq.reverse_complement()

    SeqIO.write(bseq, BOLD_SEQ.format(p), 'fasta')

# %% [markdown]
# ## Parse BLAST results

# %%
blast_dict = defaultdict(dict)

for plate in range(1,5):
    blast_records = NCBIXML.parse(open(XML.format(plate)))
    for record in blast_records:
        # parse sample name
        marker_seq_name = record.query
        # non-empty samples
        seq_name = marker_seq_name
        if not marker_seq_name.startswith('empty'):
            seq_name = marker_seq_name.split('_')[0]
            # african samples
            if not seq_name.startswith('VBS'):
                 seq_name = 'A' + seq_name.replace('.','-')

        #blast_dict[seq_name]['sample'] = seq_name.split('_')[0]
        marker = ('COI' if plate in [1,2] else 'ITS2')
        blast_dict[seq_name][marker+'_seqid'] = marker_seq_name
        blast_dict[seq_name][marker+'_length'] = record.query_length
        blast_dict[seq_name][marker+'_num_alignments'] = len(record.alignments)

        match_spp = []
        # within-species identity thresholds COI/ITS2
        withinsp_threshold = (COI_WITHINSP_IDENTITY if plate in [1,2] else ITS2_WITHINSP_IDENTITY)
        withinsp_spp = []
        for aln in record.alignments:
            sp = '_'.join(aln.hit_def.split(' ')[:2])
            # all matching species
            if sp not in match_spp:
                match_spp.append(sp)
            # matching species with high identity
            # do not consider short matches
            if aln.hsps[0].align_length / record.query_length < MIN_WITHINSP_ALIGNED:
                continue
            # calculate identity
            identity = aln.hsps[0].identities / aln.hsps[0].align_length
            if identity >= withinsp_threshold and sp not in withinsp_spp:
                withinsp_spp.append(sp)
                
        blast_dict[seq_name][marker+'_species_predictions'] = ', '.join(withinsp_spp)
        
        if len(match_spp) > 10:
            match_spp = match_spp[:10]
        blast_dict[seq_name][marker+'_top10_species'] = ', '.join(match_spp)
        
        for i, h in enumerate(['first','second']):
            # not enough hits
            if len(record.alignments) == i:
                break
            # hit data
            hit = record.alignments[i]
            prefix = '{}_{}_hit'.format(marker, h)
            blast_dict[seq_name][prefix] = hit.hit_id
            blast_dict[seq_name][prefix+'_species'] = '_'.join(hit.hit_def.split(' ')[:2])
            blast_dict[seq_name][prefix+'_hsps'] = len(hit.hsps)
            blast_dict[seq_name][prefix+'_length'] = hit.hsps[0].align_length
            blast_dict[seq_name][prefix+'_identities'] = hit.hsps[0].identities
            blast_dict[seq_name][prefix+'_identity'] = hit.hsps[0].identities / hit.hsps[0].align_length * 100
            blast_dict[seq_name][prefix+'_score'] = hit.hsps[0].score

# %%
blast_df = pd.DataFrame(blast_dict).T
blast_df
# Out:
#                                       COI_first_hit COI_first_hit_hsps  \
# VBS00156               gi|1699503525|gb|MK685245.1|                  1
# VBS00157               gi|1699503525|gb|MK685245.1|                  1
# VBS00158               gi|1755716158|gb|MK628547.1|                  1
# Abro-22                 gi|656438847|gb|KJ522835.1|                  1
# Abro-30                 gi|656438861|gb|KJ522842.1|                  1
# Abro-33                 gi|656438861|gb|KJ522842.1|                  1
# Acol-554               gi|1573759805|gb|MK300237.1|                  1
# Acol-558               gi|1573759805|gb|MK300237.1|                  1
# Acol-570               gi|1573759805|gb|MK300237.1|                  1
# Acol-645               gi|1573759797|gb|MK300233.1|                  1
# Acon-142               gi|1573759807|gb|MK300238.1|                  1
# Acou-71                 gi|656438841|gb|KJ522831.1|                  1
# Acou-80                 gi|656438841|gb|KJ522831.1|                  1
# Acou-956                gi|927324894|gb|KR014843.1|                  1
# Acou-959                gi|656438841|gb|KJ522831.1|                  1
# Acou-962                gi|656438841|gb|KJ522831.1|                  1
# Adem-19                 gi|656438861|gb|KJ522842.1|                  1
# Adem-32                 gi|656438861|gb|KJ522842.1|                  1
# Adur-97-3               gi|656438861|gb|KJ522842.1|                  1
# Adur-97-4               gi|656438861|gb|KJ522842.1|                  1
# Adur-97-5               gi|656438861|gb|KJ522842.1|                  1
# Adur-97-6               gi|656438861|gb|KJ522842.1|                  1
# Adur-97-7               gi|656438861|gb|KJ522842.1|                  1
# Afun-1                 gi|1451237868|gb|MH299890.1|                  1
# Afun-3                 gi|1451237864|gb|MH299888.1|                  1
# Afun-9                 gi|1573759793|gb|MK300231.1|                  1
# Afun-11                gi|1573759793|gb|MK300231.1|                  1
# Afun-13                gi|1451237864|gb|MH299888.1|                  1
# Agab-M192              gi|1018445155|gb|KU948655.1|                  1
# Agab-M203              gi|1018445155|gb|KU948655.1|                  1
# ...                                             ...                ...
# VBS00128               gi|1751539189|gb|MK603828.1|                  1
# VBS00144                gi|937958043|gb|KT382821.1|                  1
# VBS00146                gi|937958043|gb|KT382821.1|                  1
# VBS00147                gi|937958043|gb|KT382821.1|                  1
# VBS00148                gi|937958043|gb|KT382821.1|                  1
# VBS00150               gi|1383770373|gb|MF179270.1|                  1
# VBS00154               gi|1578806634|gb|MH425411.1|                  1
# Acar-191               gi|1380944211|gb|MF381675.1|                  1
# Acar-192                gi|927324883|gb|KR014837.1|                  1
# Acar-193                gi|927324883|gb|KR014837.1|                  1
# Acar-194                gi|927324883|gb|KR014837.1|                  1
# Acar-195                gi|927324883|gb|KR014837.1|                  1
# empty_B07-HCO2198.ab1   gi|927324909|gb|KR014851.1|                  1
# VBS00145                                        NaN                NaN
# VBS00149                                        NaN                NaN
# Abro-21                                         NaN                NaN
# Adem-34                                         NaN                NaN
# Agam-30                                         NaN                NaN
# Agam-32                                         NaN                NaN
# Agam-35                                         NaN                NaN
# Ajab-B612                                       NaN                NaN
# Amou-2-5                                        NaN                NaN
# Apal-269                                        NaN                NaN
# VBS00001                                        NaN                NaN
# VBS00050                                        NaN                NaN
# empty_B05-ITS2A.ab1                             NaN                NaN
# empty_B07-ITS2A.ab1                             NaN                NaN
# empty_G08-ITS2A.ab1                             NaN                NaN
# empty_H07-ITS2A.ab1                             NaN                NaN
# VBS00021                                        NaN                NaN
#
#                       COI_first_hit_identities COI_first_hit_identity  \
# VBS00156                                   596                98.8391
# VBS00157                                   598                99.1708
# VBS00158                                   607                 99.183
# Abro-22                                    368                94.8454
# Abro-30                                    580                94.1558
# Abro-33                                    581                94.3182
# Acol-554                                   616                    100
# Acol-558                                   616                    100
# Acol-570                                   614                99.6753
# Acol-645                                   611                99.1883
# Acon-142                                   560                90.9091
# Acou-71                                    610                 99.026
# Acou-80                                    611                99.1883
# Acou-956                                   613                 99.513
# Acou-959                                   612                99.3506
# Acou-962                                   610                 99.026
# Adem-19                                    581                94.3182
# Adem-32                                    580                94.1558
# Adur-97-3                                  563                91.3961
# Adur-97-4                                  563                91.3961
# Adur-97-5                                  563                91.3961
# Adur-97-6                                  563                91.3961
# Adur-97-7                                  562                91.2338
# Afun-1                                     228                    100
# Afun-3                                     401                99.7512
# Afun-9                                     614                99.6753
# Afun-11                                    615                99.8377
# Afun-13                                    463                    100
# Agab-M192                                  569                94.3615
# Agab-M203                                  569                94.3615
# ...                                        ...                    ...
# VBS00128                                   614                99.5138
# VBS00144                                   608                98.2229
# VBS00146                                   616                99.5153
# VBS00147                                   607                98.0614
# VBS00148                                   605                97.7383
# VBS00150                                   430                95.1327
# VBS00154                                   593                99.4966
# Acar-191                                   574                92.5806
# Acar-192                                   548                94.3201
# Acar-193                                   549                94.4923
# Acar-194                                   550                94.6644
# Acar-195                                   549                94.4923
# empty_B07-HCO2198.ab1                      215                98.6239
# VBS00145                                   NaN                    NaN
# VBS00149                                   NaN                    NaN
# Abro-21                                    NaN                    NaN
# Adem-34                                    NaN                    NaN
# Agam-30                                    NaN                    NaN
# Agam-32                                    NaN                    NaN
# Agam-35                                    NaN                    NaN
# Ajab-B612                                  NaN                    NaN
# Amou-2-5                                   NaN                    NaN
# Apal-269                                   NaN                    NaN
# VBS00001                                   NaN                    NaN
# VBS00050                                   NaN                    NaN
# empty_B05-ITS2A.ab1                        NaN                    NaN
# empty_B07-ITS2A.ab1                        NaN                    NaN
# empty_G08-ITS2A.ab1                        NaN                    NaN
# empty_H07-ITS2A.ab1                        NaN                    NaN
# VBS00021                                   NaN                    NaN
#
#                       COI_first_hit_length COI_first_hit_score  \
# VBS00156                               603                 582
# VBS00157                               603                 588
# VBS00158                               612                 597
# Abro-22                                388                 328
# Abro-30                                616                 508
# Abro-33                                616                 511
# Acol-554                               616                 616
# Acol-558                               616                 616
# Acol-570                               616                 610
# Acol-645                               616                 601
# Acon-142                               616                 448
# Acou-71                                616                 600
# Acou-80                                616                 603
# Acou-956                               616                 609
# Acou-959                               616                 606
# Acou-962                               616                 600
# Adem-19                                616                 511
# Adem-32                                616                 508
# Adur-97-3                              616                 457
# Adur-97-4                              616                 457
# Adur-97-5                              616                 457
# Adur-97-6                              616                 457
# Adur-97-7                              616                 454
# Afun-1                                 228                 228
# Afun-3                                 402                 399
# Afun-9                                 616                 610
# Afun-11                                616                 613
# Afun-13                                463                 463
# Agab-M192                              603                 501
# Agab-M203                              603                 501
# ...                                    ...                 ...
# VBS00128                               617                 608
# VBS00144                               619                 586
# VBS00146                               619                 610
# VBS00147                               619                 583
# VBS00148                               619                 577
# VBS00150                               452                 386
# VBS00154                               596                 587
# Acar-191                               620                 481
# Acar-192                               581                 482
# Acar-193                               581                 485
# Acar-194                               581                 488
# Acar-195                               581                 485
# empty_B07-HCO2198.ab1                  218                 210
# VBS00145                               NaN                 NaN
# VBS00149                               NaN                 NaN
# Abro-21                                NaN                 NaN
# Adem-34                                NaN                 NaN
# Agam-30                                NaN                 NaN
# Agam-32                                NaN                 NaN
# Agam-35                                NaN                 NaN
# Ajab-B612                              NaN                 NaN
# Amou-2-5                               NaN                 NaN
# Apal-269                               NaN                 NaN
# VBS00001                               NaN                 NaN
# VBS00050                               NaN                 NaN
# empty_B05-ITS2A.ab1                    NaN                 NaN
# empty_B07-ITS2A.ab1                    NaN                 NaN
# empty_G08-ITS2A.ab1                    NaN                 NaN
# empty_H07-ITS2A.ab1                    NaN                 NaN
# VBS00021                               NaN                 NaN
#
#                         COI_first_hit_species COI_length COI_num_alignments  \
# VBS00156                      Anopheles_vagus        616                500
# VBS00157                      Anopheles_vagus        616                500
# VBS00158                      Anopheles_vagus        616                500
# Abro-22                         Anopheles_sp.        391                500
# Abro-30                         Anopheles_sp.        616                500
# Abro-33                         Anopheles_sp.        616                500
# Acol-554                    Anopheles_gambiae        616                500
# Acol-558                    Anopheles_gambiae        616                500
# Acol-570                    Anopheles_gambiae        616                500
# Acol-645                    Anopheles_gambiae        616                500
# Acon-142                    Anopheles_gambiae        616                500
# Acou-71                    Anopheles_coustani        616                500
# Acou-80                    Anopheles_coustani        616                500
# Acou-956                        Anopheles_cf.        616                500
# Acou-959                   Anopheles_coustani        616                500
# Acou-962                   Anopheles_coustani        616                500
# Adem-19                         Anopheles_sp.        616                500
# Adem-32                         Anopheles_sp.        616                500
# Adur-97-3                       Anopheles_sp.        616                500
# Adur-97-4                       Anopheles_sp.        616                500
# Adur-97-5                       Anopheles_sp.        616                500
# Adur-97-6                       Anopheles_sp.        616                500
# Adur-97-7                       Anopheles_sp.        616                500
# Afun-1                     Anopheles_funestus        228                500
# Afun-3                     Anopheles_funestus        402                500
# Afun-9                     Anopheles_funestus        616                500
# Afun-11                    Anopheles_funestus        616                500
# Afun-13                    Anopheles_funestus        463                500
# Agab-M192                       Anopheles_sp.        616                500
# Agab-M203                       Anopheles_sp.        616                500
# ...                                       ...        ...                ...
# VBS00128                  Anopheles_subpictus        619                500
# VBS00144                 Anopheles_epiroticus        619                500
# VBS00146                 Anopheles_epiroticus        619                500
# VBS00147                 Anopheles_epiroticus        619                500
# VBS00148                 Anopheles_epiroticus        619                500
# VBS00150                Anopheles_tessellatus        452                500
# VBS00154                      Anopheles_vagus        619                500
# Acar-191                   Anopheles_darlingi        620                500
# Acar-192                       Anopheles_nili        619                500
# Acar-193                       Anopheles_nili        619                500
# Acar-194                       Anopheles_nili        619                500
# Acar-195                       Anopheles_nili        619                500
# empty_B07-HCO2198.ab1  Anopheles_maculipalpis        218                500
# VBS00145                                  NaN        NaN                NaN
# VBS00149                                  NaN        NaN                NaN
# Abro-21                                   NaN        NaN                NaN
# Adem-34                                   NaN        NaN                NaN
# Agam-30                                   NaN        NaN                NaN
# Agam-32                                   NaN        NaN                NaN
# Agam-35                                   NaN        NaN                NaN
# Ajab-B612                                 NaN        NaN                NaN
# Amou-2-5                                  NaN        NaN                NaN
# Apal-269                                  NaN        NaN                NaN
# VBS00001                                  NaN        NaN                NaN
# VBS00050                                  NaN        NaN                NaN
# empty_B05-ITS2A.ab1                       NaN        NaN                NaN
# empty_B07-ITS2A.ab1                       NaN        NaN                NaN
# empty_G08-ITS2A.ab1                       NaN        NaN                NaN
# empty_H07-ITS2A.ab1                       NaN        NaN                NaN
# VBS00021                                  NaN        NaN                NaN
#
#                                      COI_second_hit  ...  \
# VBS00156               gi|1578806696|gb|MH425442.1|  ...
# VBS00157               gi|1578806696|gb|MH425442.1|  ...
# VBS00158               gi|1383770353|gb|MF179260.1|  ...
# Abro-22                 gi|656438851|gb|KJ522837.1|  ...
# Abro-30                 gi|656438847|gb|KJ522835.1|  ...
# Abro-33                 gi|656438847|gb|KJ522835.1|  ...
# Acol-554               gi|1573759799|gb|MK300234.1|  ...
# Acol-558               gi|1573759799|gb|MK300234.1|  ...
# Acol-570               gi|1573759799|gb|MK300234.1|  ...
# Acol-645               gi|1382879396|gb|MG753704.1|  ...
# Acon-142               gi|1382879746|gb|MG753729.1|  ...
# Acou-71                 gi|927324894|gb|KR014843.1|  ...
# Acou-80                 gi|927324894|gb|KR014843.1|  ...
# Acou-956                gi|927324889|gb|KR014840.1|  ...
# Acou-959                gi|927324894|gb|KR014843.1|  ...
# Acou-962                gi|927324894|gb|KR014843.1|  ...
# Adem-19                 gi|656438847|gb|KJ522835.1|  ...
# Adem-32                 gi|656438847|gb|KJ522835.1|  ...
# Adur-97-3              gi|1380942979|gb|MF381587.1|  ...
# Adur-97-4              gi|1380942979|gb|MF381587.1|  ...
# Adur-97-5              gi|1380942979|gb|MF381587.1|  ...
# Adur-97-6              gi|1380942979|gb|MF381587.1|  ...
# Adur-97-7              gi|1380942979|gb|MF381587.1|  ...
# Afun-1                 gi|1451237864|gb|MH299888.1|  ...
# Afun-3                 gi|1451237860|gb|MH299886.1|  ...
# Afun-9                  gi|927324901|gb|KR014847.1|  ...
# Afun-11                 gi|927324901|gb|KR014847.1|  ...
# Afun-13                gi|1451237860|gb|MH299886.1|  ...
# Agab-M192               gi|937958029|gb|KT382820.1|  ...
# Agab-M203               gi|937958029|gb|KT382820.1|  ...
# ...                                             ...  ...
# VBS00128                gi|627531444|gb|KJ461792.1|  ...
# VBS00144               gi|1380943973|gb|MF381658.1|  ...
# VBS00146                gi|402172976|gb|JX205122.1|  ...
# VBS00147               gi|474420649|dbj|AB738146.1|  ...
# VBS00148               gi|1380943973|gb|MF381658.1|  ...
# VBS00150               gi|1383770369|gb|MF179268.1|  ...
# VBS00154               gi|1755716158|gb|MK628547.1|  ...
# Acar-191               gi|1380943273|gb|MF381608.1|  ...
# Acar-192                gi|656438841|gb|KJ522831.1|  ...
# Acar-193                gi|656438841|gb|KJ522831.1|  ...
# Acar-194                gi|656438841|gb|KJ522831.1|  ...
# Acar-195                gi|656438841|gb|KJ522831.1|  ...
# empty_B07-HCO2198.ab1  gi|1447726759|gb|MH384978.1|  ...
# VBS00145                                        NaN  ...
# VBS00149                                        NaN  ...
# Abro-21                                         NaN  ...
# Adem-34                                         NaN  ...
# Agam-30                                         NaN  ...
# Agam-32                                         NaN  ...
# Agam-35                                         NaN  ...
# Ajab-B612                                       NaN  ...
# Amou-2-5                                        NaN  ...
# Apal-269                                        NaN  ...
# VBS00001                                        NaN  ...
# VBS00050                                        NaN  ...
# empty_B05-ITS2A.ab1                             NaN  ...
# empty_B07-ITS2A.ab1                             NaN  ...
# empty_G08-ITS2A.ab1                             NaN  ...
# empty_H07-ITS2A.ab1                             NaN  ...
# VBS00021                                        NaN  ...
#
#                                     ITS2_second_hit ITS2_second_hit_hsps  \
# VBS00156               gi|1698454428|gb|MN148589.1|                    1
# VBS00157               gi|1698454428|gb|MN148589.1|                    1
# VBS00158               gi|1698454428|gb|MN148589.1|                    1
# Abro-22                 gi|374676298|gb|JN994151.1|                    1
# Abro-30                 gi|374676298|gb|JN994151.1|                    1
# Abro-33                 gi|374676298|gb|JN994151.1|                    1
# Acol-554               gi|1727559942|gb|MN335028.1|                    1
# Acol-558               gi|1727559942|gb|MN335028.1|                    1
# Acol-570               gi|1727559942|gb|MN335028.1|                    1
# Acol-645                gi|374676293|gb|JN994146.1|                    1
# Acon-142                                        NaN                  NaN
# Acou-71                gi|1421469817|gb|MH598414.1|                    1
# Acou-80                 gi|927324853|gb|KR014824.1|                    1
# Acou-956                gi|374676281|gb|JN994134.1|                    1
# Acou-959                gi|656438821|gb|KJ522815.1|                    1
# Acou-962                gi|656438821|gb|KJ522815.1|                    1
# Adem-19                 gi|374676298|gb|JN994151.1|                    1
# Adem-32                 gi|374676298|gb|JN994151.1|                    1
# Adur-97-3              gi|1246951746|gb|MF535232.1|                    1
# Adur-97-4               gi|992322083|gb|KU312215.1|                    1
# Adur-97-5                                       NaN                  NaN
# Adur-97-6                                       NaN                  NaN
# Adur-97-7               gi|927324863|gb|KR014834.1|                    1
# Afun-1                   gi|14581667|gb|AY035721.1|                    1
# Afun-3                   gi|14581667|gb|AY035721.1|                    1
# Afun-9                                          NaN                  NaN
# Afun-11                                         NaN                  NaN
# Afun-13                                         NaN                  NaN
# Agab-M192              gi|1489305219|gb|MK043039.1|                    1
# Agab-M203              gi|1489305219|gb|MK043039.1|                    1
# ...                                             ...                  ...
# VBS00128                 gi|67043498|gb|DQ013797.1|                    1
# VBS00144                 gi|60280545|gb|AY768540.1|                    1
# VBS00146                 gi|60280545|gb|AY768540.1|                    1
# VBS00147                 gi|60280545|gb|AY768540.1|                    1
# VBS00148                 gi|60280545|gb|AY768540.1|                    1
# VBS00150                gi|187672168|gb|EU650425.1|                    1
# VBS00154               gi|1698454428|gb|MN148589.1|                    1
# Acar-191                gi|471756220|gb|KC189966.1|                    1
# Acar-192                gi|471756220|gb|KC189966.1|                    1
# Acar-193                gi|471756220|gb|KC189966.1|                    1
# Acar-194                gi|471756220|gb|KC189966.1|                    1
# Acar-195                gi|471756220|gb|KC189966.1|                    1
# empty_B07-HCO2198.ab1                           NaN                  NaN
# VBS00145                gi|673542080|gb|KJ746977.1|                    1
# VBS00149                gi|187672168|gb|EU650425.1|                    1
# Abro-21                 gi|374676298|gb|JN994151.1|                    1
# Adem-34                 gi|374676298|gb|JN994151.1|                    1
# Agam-30                gi|1727559925|gb|MN335011.1|                    1
# Agam-32                gi|1421469845|gb|MH598442.1|                    1
# Agam-35                gi|1727559925|gb|MN335011.1|                    1
# Ajab-B612                                       NaN                  NaN
# Amou-2-5               gi|1421469827|gb|MH598424.1|                    1
# Apal-269                gi|927324853|gb|KR014824.1|                    1
# VBS00001               gi|1189430035|gb|KY000681.1|                    1
# VBS00050                gi|821372068|gb|KP298423.1|                    1
# empty_B05-ITS2A.ab1     gi|471756266|gb|KC189969.1|                    1
# empty_B07-ITS2A.ab1    gi|1509775474|gb|MK129244.1|                    1
# empty_G08-ITS2A.ab1     gi|471756220|gb|KC189966.1|                    1
# empty_H07-ITS2A.ab1     gi|471756220|gb|KC189966.1|                    1
# VBS00021                gi|659134963|gb|KJ661001.1|                   18
#
#                       ITS2_second_hit_identities ITS2_second_hit_identity  \
# VBS00156                                     650                      100
# VBS00157                                     650                      100
# VBS00158                                     645                      100
# Abro-22                                      438                  91.0603
# Abro-30                                      438                  91.0603
# Abro-33                                      439                  91.4583
# Acol-554                                     523                      100
# Acol-558                                     522                  99.6183
# Acol-570                                     522                  99.6183
# Acol-645                                     518                   98.855
# Acon-142                                     NaN                      NaN
# Acou-71                                      534                  98.8889
# Acou-80                                      244                  98.7854
# Acou-956                                     576                  99.8267
# Acou-959                                     250                      100
# Acou-962                                     576                   99.654
# Adem-19                                      438                  91.0603
# Adem-32                                      438                    91.25
# Adur-97-3                                     47                       94
# Adur-97-4                                     40                  95.2381
# Adur-97-5                                    NaN                      NaN
# Adur-97-6                                    NaN                      NaN
# Adur-97-7                                     46                  95.8333
# Afun-1                                       772                  99.4845
# Afun-3                                       772                  99.4845
# Afun-9                                       NaN                      NaN
# Afun-11                                      NaN                      NaN
# Afun-13                                      NaN                      NaN
# Agab-M192                                    399                  81.0976
# Agab-M203                                    399                  80.9331
# ...                                          ...                      ...
# VBS00128                                     444                  99.7753
# VBS00144                                     552                      100
# VBS00146                                     552                      100
# VBS00147                                     552                      100
# VBS00148                                     552                      100
# VBS00150                                     511                  96.7803
# VBS00154                                     645                      100
# Acar-191                                     334                     83.5
# Acar-192                                     335                    83.75
# Acar-193                                     330                  83.3333
# Acar-194                                     331                  83.5859
# Acar-195                                     330                  83.3333
# empty_B07-HCO2198.ab1                        NaN                      NaN
# VBS00145                                     406                      100
# VBS00149                                     499                  97.0817
# Abro-21                                      438                  91.0603
# Adem-34                                      432                  91.3319
# Agam-30                                      524                      100
# Agam-32                                      176                   99.435
# Agam-35                                      522                  99.6183
# Ajab-B612                                    NaN                      NaN
# Amou-2-5                                     455                  99.5624
# Apal-269                                     562                  96.8966
# VBS00001                                     422                  98.3683
# VBS00050                                     806                  99.3835
# empty_B05-ITS2A.ab1                           64                  96.9697
# empty_B07-ITS2A.ab1                          206                   95.814
# empty_G08-ITS2A.ab1                          181                  79.7357
# empty_H07-ITS2A.ab1                          316                       79
# VBS00021                                    1020                  99.6094
#
#                       ITS2_second_hit_length ITS2_second_hit_score  \
# VBS00156                                 650                   650
# VBS00157                                 650                   650
# VBS00158                                 645                   645
# Abro-22                                  481                   344
# Abro-30                                  481                   344
# Abro-33                                  480                   350
# Acol-554                                 523                   523
# Acol-558                                 524                   517
# Acol-570                                 524                   517
# Acol-645                                 524                   506
# Acon-142                                 NaN                   NaN
# Acou-71                                  540                   521
# Acou-80                                  247                   238
# Acou-956                                 577                   574
# Acou-959                                 250                   250
# Acou-962                                 578                   574
# Adem-19                                  481                   344
# Adem-32                                  480                   347
# Adur-97-3                                 50                    41
# Adur-97-4                                 42                    36
# Adur-97-5                                NaN                   NaN
# Adur-97-6                                NaN                   NaN
# Adur-97-7                                 48                    42
# Afun-1                                   776                   764
# Afun-3                                   776                   764
# Afun-9                                   NaN                   NaN
# Afun-11                                  NaN                   NaN
# Afun-13                                  NaN                   NaN
# Agab-M192                                492                   195
# Agab-M203                                493                   193
# ...                                      ...                   ...
# VBS00128                                 445                   441
# VBS00144                                 552                   552
# VBS00146                                 552                   552
# VBS00147                                 552                   552
# VBS00148                                 552                   552
# VBS00150                                 528                   474
# VBS00154                                 645                   645
# Acar-191                                 400                   183
# Acar-192                                 400                   186
# Acar-193                                 396                   179
# Acar-194                                 396                   182
# Acar-195                                 396                   179
# empty_B07-HCO2198.ab1                    NaN                   NaN
# VBS00145                                 406                   406
# VBS00149                                 514                   467
# Abro-21                                  481                   344
# Adem-34                                  473                   343
# Agam-30                                  524                   524
# Agam-32                                  177                   173
# Agam-35                                  524                   518
# Ajab-B612                                NaN                   NaN
# Amou-2-5                                 457                   450
# Apal-269                                 580                   525
# VBS00001                                 429                   407
# VBS00050                                 811                   795
# empty_B05-ITS2A.ab1                       66                    59
# empty_B07-ITS2A.ab1                      215                   187
# empty_G08-ITS2A.ab1                      227                    73
# empty_H07-ITS2A.ab1                      400                   129
# VBS00021                                1024                  1011
#
#                          ITS2_second_hit_species              ITS2_seqid  \
# VBS00156                         Anopheles_vagus  VBS00156_A06-ITS2A.ab1
# VBS00157                         Anopheles_vagus  VBS00157_E06-ITS2A.ab1
# VBS00158                         Anopheles_vagus  VBS00158_H06-ITS2A.ab1
# Abro-22                       Anopheles_theileri    bro.22_B10-ITS2A.ab1
# Abro-30                       Anopheles_theileri    bro.30_C10-ITS2A.ab1
# Abro-33                       Anopheles_theileri    bro.33_D10-ITS2A.ab1
# Acol-554                       Anopheles_gambiae   col.554_D08-ITS2A.ab1
# Acol-558                       Anopheles_gambiae   col.558_E08-ITS2A.ab1
# Acol-570                       Anopheles_gambiae   col.570_F08-ITS2A.ab1
# Acol-645               Anopheles_quadriannulatus   col.645_G08-ITS2A.ab1
# Acon-142                                     NaN                     NaN
# Acou-71                            Anopheles_sp.    cou.71_H02-ITS2A.ab1
# Acou-80                            Anopheles_cf.    cou.80_A03-ITS2A.ab1
# Acou-956                      Anopheles_coustani   cou.956_B03-ITS2A.ab1
# Acou-959                      Anopheles_coustani   cou.959_D03-ITS2A.ab1
# Acou-962                      Anopheles_coustani   cou.962_C03-ITS2A.ab1
# Adem-19                       Anopheles_theileri    dem.19_F09-ITS2A.ab1
# Adem-32                       Anopheles_theileri    dem.32_G09-ITS2A.ab1
# Adur-97-3                     Anopheles_aconitus  dur.97.3_C02-ITS2A.ab1
# Adur-97-4                       Anopheles_pullus  dur.97.4_D02-ITS2A.ab1
# Adur-97-5                                    NaN  dur.97.5_E02-ITS2A.ab1
# Adur-97-6                                    NaN                     NaN
# Adur-97-7                      Anopheles_leesoni  dur.97.7_G02-ITS2A.ab1
# Afun-1                        Anopheles_funestus     fun.1_B06-ITS2A.ab1
# Afun-3                        Anopheles_funestus     fun.3_C06-ITS2A.ab1
# Afun-9                                       NaN                     NaN
# Afun-11                                      NaN                     NaN
# Afun-13                                      NaN                     NaN
# Agab-M192                          Anopheles_sp.  gab.M192_E11-ITS2A.ab1
# Agab-M203                          Anopheles_sp.  gab.M203_F11-ITS2A.ab1
# ...                                          ...                     ...
# VBS00128                      Anopheles_pallidus  VBS00128_H04-ITS2A.ab1
# VBS00144                     Anopheles_sundaicus  VBS00144_A12-ITS2A.ab1
# VBS00146                     Anopheles_sundaicus  VBS00146_C12-ITS2A.ab1
# VBS00147                     Anopheles_sundaicus  VBS00147_D12-ITS2A.ab1
# VBS00148                     Anopheles_sundaicus  VBS00148_E12-ITS2A.ab1
# VBS00150                   Anopheles_tessellatus  VBS00150_G12-ITS2A.ab1
# VBS00154                         Anopheles_vagus  VBS00154_H12-ITS2A.ab1
# Acar-191                          Anopheles_nili   car.191_B11-ITS2A.ab1
# Acar-192                          Anopheles_nili   car.192_D11-ITS2A.ab1
# Acar-193                          Anopheles_nili   car.193_A02-ITS2A.ab1
# Acar-194                          Anopheles_nili   car.194_E02-ITS2A.ab1
# Acar-195                          Anopheles_nili   car.195_A05-ITS2A.ab1
# empty_B07-HCO2198.ab1                        NaN                     NaN
# VBS00145                        Anopheles_rampae  VBS00145_B12-ITS2A.ab1
# VBS00149                   Anopheles_tessellatus  VBS00149_F12-ITS2A.ab1
# Abro-21                       Anopheles_theileri    bro.21_A10-ITS2A.ab1
# Adem-34                       Anopheles_theileri    dem.34_H09-ITS2A.ab1
# Agam-30                        Anopheles_gambiae    gam.30_A07-ITS2A.ab1
# Agam-32                        Anopheles_gambiae    gam.32_C07-ITS2A.ab1
# Agam-35                        Anopheles_gambiae    gam.35_C08-ITS2A.ab1
# Ajab-B612                                    NaN  jab.B612_F10-ITS2A.ab1
# Amou-2-5                      Anopheles_moucheti   mou.2.5_E01-ITS2A.ab1
# Apal-269                           Anopheles_cf.   pal.269_H08-ITS2A.ab1
# VBS00001                     Anopheles_annularis  VBS00001_A01-ITS2A.ab1
# VBS00050                         Anopheles_dirus  VBS00050_D02-ITS2A.ab1
# empty_B05-ITS2A.ab1               Anopheles_nili     empty_B05-ITS2A.ab1
# empty_B07-ITS2A.ab1       Anopheles_maculipalpis     empty_B07-ITS2A.ab1
# empty_G08-ITS2A.ab1               Anopheles_nili     empty_G08-ITS2A.ab1
# empty_H07-ITS2A.ab1               Anopheles_nili     empty_H07-ITS2A.ab1
# VBS00021                  Anopheles_barbirostris  VBS00021_E01-ITS2A.ab1
#
#                                                 ITS2_species_predictions  \
# VBS00156                                  Anopheles_vagus, Anopheles_sp.
# VBS00157                                  Anopheles_vagus, Anopheles_sp.
# VBS00158                                  Anopheles_vagus, Anopheles_sp.
# Abro-22
# Abro-30
# Abro-33
# Acol-554               Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Acol-558               Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Acol-570               Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Acol-645               Anopheles_quadriannulatus, Anopheles_gambiae, ...
# Acon-142                                                             NaN
# Acou-71                                                    Anopheles_sp.
# Acou-80                                     Anopheles_sp., Anopheles_cf.
# Acou-956                                              Anopheles_coustani
# Acou-959                                              Anopheles_coustani
# Acou-962                                              Anopheles_coustani
# Adem-19
# Adem-32
# Adur-97-3
# Adur-97-4
# Adur-97-5
# Adur-97-6                                                            NaN
# Adur-97-7
# Afun-1                                                Anopheles_funestus
# Afun-3                                                Anopheles_funestus
# Afun-9                                                               NaN
# Afun-11                                                              NaN
# Afun-13                                                              NaN
# Agab-M192
# Agab-M203
# ...                                                                  ...
# VBS00128               Anopheles_jamesii, Anopheles_pallidus, Anophel...
# VBS00144               Anopheles_epiroticus, Anopheles_sundaicus, Ano...
# VBS00146               Anopheles_epiroticus, Anopheles_sundaicus, Ano...
# VBS00147               Anopheles_epiroticus, Anopheles_sundaicus, Ano...
# VBS00148               Anopheles_epiroticus, Anopheles_sundaicus, Ano...
# VBS00150                                           Anopheles_tessellatus
# VBS00154                                  Anopheles_vagus, Anopheles_sp.
# Acar-191                                            Anopheles_carnevalei
# Acar-192                                            Anopheles_carnevalei
# Acar-193
# Acar-194                                            Anopheles_carnevalei
# Acar-195
# empty_B07-HCO2198.ab1                                                NaN
# VBS00145               Anopheles_sp., Anopheles_rampae, Anopheles_cf....
# VBS00149                                           Anopheles_tessellatus
# Abro-21
# Adem-34
# Agam-30                Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Agam-32                Anopheles_gambiae, Anopheles_coluzzii, Anophel...
# Agam-35                Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Ajab-B612
# Amou-2-5                                              Anopheles_moucheti
# Apal-269                                                   Anopheles_sp.
# VBS00001                                             Anopheles_annularis
# VBS00050                                  Anopheles_dirus, Anopheles_sp.
# empty_B05-ITS2A.ab1
# empty_B07-ITS2A.ab1
# empty_G08-ITS2A.ab1
# empty_H07-ITS2A.ab1
# VBS00021                     Anopheles_barbirostris, Anopheles_dissidens
#
#                                                       ITS2_top10_species
# VBS00156               Anopheles_vagus, Anopheles_sp., Anopheles_subp...
# VBS00157               Anopheles_vagus, Anopheles_sp., Anopheles_subp...
# VBS00158               Anopheles_vagus, Anopheles_sp., Anopheles_subp...
# Abro-22                Anopheles_sp., Anopheles_theileri, Anopheles_m...
# Abro-30                Anopheles_sp., Anopheles_theileri, Anopheles_m...
# Abro-33                Anopheles_sp., Anopheles_theileri, Anopheles_m...
# Acol-554               Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Acol-558               Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Acol-570               Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Acol-645               Anopheles_quadriannulatus, Anopheles_gambiae, ...
# Acon-142                                                             NaN
# Acou-71                Anopheles_sp., Anopheles_cf., Anopheles_cousta...
# Acou-80                Anopheles_sp., Anopheles_cf., Anopheles_cousta...
# Acou-956               Anopheles_coustani, Anopheles_cf., Anopheles_s...
# Acou-959               Anopheles_coustani, Anopheles_sp., Anopheles_c...
# Acou-962               Anopheles_coustani, Anopheles_cf., Anopheles_s...
# Adem-19                Anopheles_sp., Anopheles_theileri, Anopheles_m...
# Adem-32                Anopheles_sp., Anopheles_theileri, Anopheles_m...
# Adur-97-3              Anopheles_minimus, Anopheles_aconitus, Anophel...
# Adur-97-4                            Anopheles_leesoni, Anopheles_pullus
# Adur-97-5
# Adur-97-6                                                            NaN
# Adur-97-7              Anopheles_leesoni, Anopheles_minimus, Anophele...
# Afun-1                 Anopheles_funestus, Anopheles_cf., Anopheles_l...
# Afun-3                 Anopheles_funestus, Anopheles_cf., Anopheles_l...
# Afun-9                                                               NaN
# Afun-11                                                              NaN
# Afun-13                                                              NaN
# Agab-M192              Anopheles_sp., Anopheles_moucheti, Anopheles_a...
# Agab-M203              Anopheles_sp., Anopheles_moucheti, Anopheles_a...
# ...                                                                  ...
# VBS00128               Anopheles_jamesii, Anopheles_pallidus, Anophel...
# VBS00144               Anopheles_epiroticus, Anopheles_sundaicus, Ano...
# VBS00146               Anopheles_epiroticus, Anopheles_sundaicus, Ano...
# VBS00147               Anopheles_epiroticus, Anopheles_sundaicus, Ano...
# VBS00148               Anopheles_epiroticus, Anopheles_sundaicus, Ano...
# VBS00150               Anopheles_tessellatus, Anopheles_annulipes, An...
# VBS00154               Anopheles_vagus, Anopheles_sp., Anopheles_subp...
# Acar-191               Anopheles_carnevalei, Anopheles_nili, Anophele...
# Acar-192               Anopheles_carnevalei, Anopheles_nili, Anophele...
# Acar-193               Anopheles_carnevalei, Anopheles_nili, Anophele...
# Acar-194               Anopheles_carnevalei, Anopheles_nili, Anophele...
# Acar-195               Anopheles_carnevalei, Anopheles_nili, Anophele...
# empty_B07-HCO2198.ab1                                                NaN
# VBS00145               Anopheles_sp., Anopheles_rampae, Anopheles_cf....
# VBS00149               Anopheles_tessellatus, Anopheles_annulipes, An...
# Abro-21                Anopheles_sp., Anopheles_theileri, Anopheles_m...
# Adem-34                Anopheles_sp., Anopheles_theileri, Anopheles_m...
# Agam-30                Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Agam-32                Anopheles_gambiae, Anopheles_coluzzii, Anophel...
# Agam-35                Anopheles_gambiae, Anopheles_quadriannulatus, ...
# Ajab-B612                                                 Anopheles_nili
# Amou-2-5               Anopheles_moucheti, Anopheles_sp., Anopheles_t...
# Apal-269               Anopheles_sp., Anopheles_cf., Anopheles_cousta...
# VBS00001               Anopheles_annularis, Anopheles_nivipes, Anophe...
# VBS00050               Anopheles_dirus, Anopheles_sp., Anopheles_crac...
# empty_B05-ITS2A.ab1    Anopheles_carnevalei, Anopheles_nili, Anophele...
# empty_B07-ITS2A.ab1    Anopheles_maculipalpis, Anopheles_maculipalpli...
# empty_G08-ITS2A.ab1    Anopheles_carnevalei, Anopheles_nili, Anophele...
# empty_H07-ITS2A.ab1    Anopheles_carnevalei, Anopheles_nili, Anophele...
# VBS00021               Anopheles_barbirostris, Anopheles_dissidens, A...
#
# [144 rows x 38 columns]

# %% [markdown]
# ## Add BOLD species predictions

# %%
# collect bold results
bold_dfs = []

for i in [1,2]:
    bold_df = pd.read_csv(BOLD_TSV.format(i), sep='\t')
    bold_dfs.append(bold_df)
bold_df = pd.concat(bold_dfs)
print(bold_df.shape)
bold_df.head()
# Out:
# (127, 5)
#                    Query ID          Best ID             Search DB  Top %  \
# 0  VBS00156_E09-HCO2198.ab1  Anopheles vagus  COI SPECIES DATABASE  99.33
# 1  VBS00157_H09-HCO2198.ab1  Anopheles vagus  COI SPECIES DATABASE  99.66
# 2  VBS00158_B11-HCO2198.ab1  Anopheles vagus  COI SPECIES DATABASE  99.32
# 3    bro.22_B10-HCO2198.ab1         No match  COI SPECIES DATABASE    NaN
# 4    bro.30_C10-HCO2198.ab1         No match  COI SPECIES DATABASE    NaN
#
#    Low %
# 0  89.72
# 1  90.07
# 2  89.74
# 3    NaN
# 4    NaN

# %%
# adjust bold results
bold_df.columns = 'bold_' + bold_df.columns.str.lower().str.replace(' ','_')
bold_df['bold_best_id'] = bold_df.bold_best_id.str.replace(' ','_')
bold_df['sample'] = bold_df.bold_query_id
non_empty = ~bold_df['sample'].str.startswith('empty')
non_vbs = ~bold_df['sample'].str.startswith('VBS')
bold_df.loc[non_empty, 'sample'] = bold_df.loc[non_empty, 'sample'].str.split('_').str.get(0)
bold_df.loc[non_empty & non_vbs, 'sample'] = 'A' + bold_df.loc[non_empty & non_vbs,'sample'].str.replace('.','-')
bold_df = bold_df.set_index('sample')
print(bold_df.shape)
bold_df.head()
# Out:
# (127, 5)
#                      bold_query_id     bold_best_id        bold_search_db  \
# sample
# VBS00156  VBS00156_E09-HCO2198.ab1  Anopheles_vagus  COI SPECIES DATABASE
# VBS00157  VBS00157_H09-HCO2198.ab1  Anopheles_vagus  COI SPECIES DATABASE
# VBS00158  VBS00158_B11-HCO2198.ab1  Anopheles_vagus  COI SPECIES DATABASE
# Abro-22     bro.22_B10-HCO2198.ab1         No_match  COI SPECIES DATABASE
# Abro-30     bro.30_C10-HCO2198.ab1         No_match  COI SPECIES DATABASE
#
#           bold_top_%  bold_low_%
# sample
# VBS00156       99.33       89.72
# VBS00157       99.66       90.07
# VBS00158       99.32       89.74
# Abro-22          NaN         NaN
# Abro-30          NaN         NaN

# %%
comb_df = pd.merge(blast_df, bold_df, how='outer', left_index=True, right_index=True)
comb_df.shape
# Out:
# (144, 43)

# %% [markdown]
# ## Add partner and ampseq species predictions

# %%
# read sample metadata, remove duplicate row
sm_df = pd.read_csv(SAMPLE_META, index_col=0)
sm_df = sm_df[~sm_df.index.duplicated(keep='first')]
sm_df.shape
# Out:
# (163, 21)

# %%
# read amplicon sequencing species predictions matrix
ap_df = pd.read_csv(AMPSEQ_PRED, index_col=0)

# %%
# collect top predictions from ampseq
ap_dict = dict()

for sample in blast_df.index:
    ap_dict[sample] = ''

for sample, row in ap_df.iterrows():
    top_pred = row.max()
    row[row==top_pred]
    ap_dict[sample] = ', '.join(row[row==top_pred].index.to_list())

# %%
# for partner species, use series-dict-series conversion to get rid of duplicate species entries 
# (last species annotation is taken)
comb_df['partner_species'] = sm_df['Species']
comb_df['ampseq_species'] = pd.Series(ap_dict)
comb_df['amplicons_recovered'] = sm_df['Amplicons Recovered']
comb_df.shape
# Out:
# (144, 46)

# %%
cols = ('partner_species	amplicons_recovered	ampseq_species	'
'bold_best_id	bold_top_%	bold_low_%	'
'COI_length	COI_num_alignments	COI_species_predictions	COI_top10_species	'
'COI_first_hit	COI_first_hit_species	COI_first_hit_hsps	COI_first_hit_length	'
'COI_first_hit_identities	COI_first_hit_identity	COI_first_hit_score	'
'COI_second_hit	COI_second_hit_species	COI_second_hit_hsps	COI_second_hit_length	'
'COI_second_hit_identities	COI_second_hit_identity	COI_second_hit_score	'
'ITS2_length	ITS2_num_alignments	ITS2_species_predictions	ITS2_top10_species	'
'ITS2_first_hit	ITS2_first_hit_species	ITS2_first_hit_hsps	ITS2_first_hit_length	'
'ITS2_first_hit_identities	ITS2_first_hit_identity	ITS2_first_hit_score	'
'ITS2_second_hit	ITS2_second_hit_species	ITS2_second_hit_hsps	ITS2_second_hit_length	'
'ITS2_second_hit_identities	ITS2_second_hit_identity	ITS2_second_hit_score	'
'COI_seqid	ITS2_seqid').split('\t')

# %%
comb_df[cols].to_csv(SPP_PREDS)
raise Exception('Analysis ended!')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-63fc2ac463ef> in <module>
#       1 comb_df[cols].to_csv(SPP_PREDS)
# ----> 2 raise Exception('Analysis ended!')
#
# Exception: Analysis ended!

# %% [markdown]
# # Sandbox
#
# BioPython blasting via web takes about 20 minutes per sequence. Plus, complete plate cannot be sumbitted - limit for a single submission is probably around 10-20 sequences. Thus, we run blast on Sanger farm using internal copy of nt database (see blast_nt.smk).

# %%
from Bio.BLAST import NCBIWWW

# %%
# %%time
# fasta string
f = os.path.join(WD, FA.format(1))
fa_str = open(f).read()
result_handle = NCBIWWW.qblast("blastn", "nt", fa_str)
result_handle

# %%
# %%time
result_handle = NCBIWWW.qblast("blastn", "nt", records[0].seq)
result_handle

# %%
# submit each sequence separately, TODO try batching ~10 seqs - whole dataset does not work
# current timing - ca 20 (with high SD) mins per sequence
for i, record in enumerate(records):
    print(i, record.name)
    xml_file = os.path.join(WD, record.name + '.xml')
    if os.path.isfile(xml_file):
        continue
    result_handle = NCBIWWW.qblast("blastn", "nt", records[0].seq)
    with open(xml_file, "w") as out_handle:
        out_handle.write(result_handle.read())

# %%
with open(xml_file, "w") as out_handle:
    out_handle.write(result_handle.read())

# %%
records = list(SeqIO.parse(FA.format(1),format='fasta'))
records[0]

# %%
str(records[0].seq.reverse_complement())

# %%
xml_file = os.path.join(WD, 'VBS00156_E09-HCO2198.ab1.xml')
blast_record = NCBIXML.parse(open(xml_file))
plate = 1
r = list(blast_record)[0]

# %%
r.alignments[0].hit_id
