# %% [markdown]
# Create degenerate primer sequences from alignments and internal primer coordinates

# %%
import re
import sys
import pandas as pd
import numpy as np
from Bio import AlignIO
from Bio.Seq import Seq

# %%
# in
AMPL_FILE = "data/20180706_comb_ampl.maf"
PRIMER_FILE = "data/20180914_Simpledesigninfo_updated.xlsx"
# out
OUT_FILE = "data/20180918_Simpledesigninfo_updated.xlsx"

# %%
alns = list(AlignIO.parse(AMPL_FILE, "maf"))
primers = pd.read_excel(PRIMER_FILE, sheet_name=None)
primers['Multiplex_core']
# Out:
#     ID TemplateID          ForwardPrimer(Fp)          ReversePrimer(Rp)  \
# 0    1   531_cons    acattagtgctttattacgtggt     catttctttggcactttctgat
# 1    2   432_cons     acctgcattcgtatgtgttcta     ttcgaggtgggagattttcttc
# 2    3    473_var     tgctatggtacctaaacctacg       cgatgggtcaaacggaatcg
# 3    4    193_var     gccatgacgatatctacaatgc     gcgaacgctgattctaattttg
# 4    2    126_var       ttcaggagctcaccaaatcg     tccttcacctgttgtactgtat
# 5    3    416_var     aactggcactagtcatgtacat     caattaattccgttagcccgtg
# 6    4    495_var      ttcctcgcacactcatgtaag       tctcgatgtagaactgcacg
# 7    5    435_var     agttctttggagagttcggaat     aagaaaagaagtgagaaagcga
# 8    6    283_var    cacacaacttttatgtttaatca      aaaataatggccactattccc
# 9   10   205_cons      agacacaaggccttgaagaag     acagcttcttcttgtcatcgta
# 10   8      579_X         cacctgacactcgatggg         catgcagccggctacttg
# 11  10      575_X      agactttcaggccatgatacc     tcagtgaacgttgacttggtaa
# 12  17      576_X     aggagatgcaagttactatcgc       cactatcgtagcccaggttc
# 13  18      582_X         gaggcgcaggacacgatc      ctcctggatcttctgcatctc
# 14  22      587_X     tttcagcagaaacatccacatg     gtttcgatgtacttggtggttt
# 15   1  474_other    tgaattatgattaatggtgtgcc       caagtgggtgtgacattcca
# 16   3  433_other     aatgcttccattaactgccatt   ggttaagttttaatgtgcgtaaca
# 17   4  298_other  tagaattacaatcaagtggaagacg      ttatacagtggatggcagtcg
# 18   5  356_other     tctatcaccatgcacttcttgt     aatgtagataggctaaaaccgc
# 19   6  439_other     gcgcgtaatcgttttatcaaga    acaaatctgattacgatatgatc
# 20   7  269_other     aatgattcggatgatttgcttc     ccgtcattatttcccaatcaaa
# 21   9  140_other   gtgaattagattttaatgaagtaa  agtgggcagatttaattttagatct
# 22  10  245_other     cgcaattgtcacaaatctgtat       gcagtttacggcttttctcc
# 23  12   65_other       gcaaaatttccgtcccatta      tgtaattagctgtgtcttgtg
#
#     FpTm(Celsius degree)  RpTm(Celsius degree)  FpGC(%)  RpGC(%)  FpPos  \
# 0                  56.87                 56.10    34.78    36.36     18
# 1                  58.12                 58.65    40.91    45.46      5
# 2                  57.66                 59.91    45.46    55.00     46
# 3                  57.98                 57.58    45.46    40.91     16
# 4                  58.48                 57.08    50.00    40.91    123
# 5                  57.77                 58.63    40.91    45.46     19
# 6                  58.62                 58.02    47.62    50.00     68
# 7                  57.97                 56.82    40.91    36.36     48
# 8                  52.53                 54.45    26.09    38.10     53
# 9                  58.73                 58.07    47.62    40.91     41
# 10                 57.65                 59.46    61.11    61.11      0
# 11                 58.03                 58.46    47.62    40.91     11
# 12                 58.60                 58.06    45.46    55.00     24
# 13                 61.14                 58.19    66.67    52.38     24
# 14                 58.08                 57.76    40.91    40.91      6
# 15                 55.92                 58.61    34.78    50.00     13
# 16                 57.50                 57.05    36.36    33.33     23
# 17                 57.76                 58.13    36.00    47.62     52
# 18                 58.04                 56.89    40.91    40.91     40
# 19                 58.39                 52.88    40.91    30.44     47
# 20                 56.06                 55.63    36.36    36.36     12
# 21                 50.09                 57.16    20.83    32.00      2
# 22                 56.29                 57.95    36.36    50.00      8
# 23                 55.11                 54.46    40.00    38.10      4
#
#     RpPos  Penalty  AmpSize(bp) SNPs in primer?
# 0     207     1.90          190            None
# 1     217     0.65          213            None
# 2     269     3.91          224            None
# 3     249     0.42          234            None
# 4     314     0.92          192        low freq
# 5     212     0.63          194        low freq
# 6     261     2.02          194        low freq
# 7     242     1.18          195        low freq
# 8     249     4.55          197        low freq
# 9     275     0.07          235        low freq
# 10    191     5.46          192       high freq
# 11    202     0.46          192       high freq
# 12    221     2.06          198       high freq
# 13    224     1.19          201       high freq
# 14    208     0.24          203       high freq
# 15    202     2.61          190            None
# 16    212     2.95          190            None
# 17    241     1.13          190            None
# 18    239     1.11          200            None
# 19    247     6.12          201            None
# 20    214     2.37          203            None
# 21    217     3.84          216            None
# 22    230     2.05          223            None
# 23    235     4.54          232            None

# %%
def gapped_coord(seq, coord):
    '''
    Coordinate of i-th letter in sequence within gapped sequence representation
    '''
    i = 0 # nucleotides
    j = 0 # coordinates
    while i < coord:
        if str(seq[j]) != '-':
            i += 1
        j += 1
    return j
gapped_coord('-A-TA-C', 4)
# Out:
# 7

# %%
def get_primer(alignment, alnid, primer, reverse=False, min_alts=2):
    '''
    Locate primer sequence in first sequence in the alignment, 
    return primer with ambiguities coded as [ref/alt/...].
    
    reverse - primer located on reverse strand
    
    min_alts - minimum number of genomes with alt alleles to be treated as ambiguous.
    Positions with lower number of alts are converted to lowercase.
    '''
#     print(alnid)
#     print(primer)
#     print(alignment)
    
    seq = ''
    alnid = int(alnid)
    # search in 0-th sequence without gaps
    source = str(alignment[alnid][0].seq).replace('-','')
    
    if reverse:
        primer = str(Seq(primer).reverse_complement())
    pmatch = re.search(primer, source, re.IGNORECASE)
    # reverse strand primer
    if reverse:
        for i in range(gapped_coord(alignment[alnid][0], pmatch.end()) - 1,
                       gapped_coord(alignment[alnid][0], pmatch.start()) - 1,
                       -1):
            col = [str(Seq(nt).reverse_complement()) for nt in alignment[alnid][:, i]]
            ref = col[0]
            alt = set(col)
            alt.remove(ref)
            if len(alt) == 0: # no alts
                seq += ref
            elif len(alt) == 1 and col.count(''.join(alt)) < min_alts: # single occurence of alt in alignment
                seq += ref.lower()
            else:
                #print(''.join(col))
                seq += '[{}/{}]'.format(ref, '/'.join(alt))
    # forward strand primer
    else:
        for i in range(gapped_coord(alignment[alnid][0], pmatch.start()), gapped_coord(alignment[alnid][0], pmatch.end())):
            col = alignment[alnid][:, i]
            ref = col[0]
            alt = set(col)
            alt.remove(ref)
            if len(set(col)) == 1:
                seq += ref
            elif len(alt) == 1 and col.count(''.join(alt)) < min_alts: # single occurence of alt in alignment
                seq += ref.lower()
            else:
                alt = set(col)
                alt.remove(ref)
                seq += '[{}/{}]'.format(ref, '/'.join(alt))
    
    # reverse
    
        
    return seq

print(get_primer(alns, 508, 'ccttcatgaacagacggttgt'))
print(get_primer(alns, 508, 'gagcacatcattgccggt', reverse=True))
# Out:
# CCTTCATgAACAGACGGTTGT
# GAGCACAT[C/T]AT[T/C]GCCGGT

# %%
primers['Multiplex_core']['AlnID'] = primers['Multiplex_core']['TemplateID'] \
                                        .str.split('_').apply(lambda x: int(x[0]))
# vectorize primer search, excluded - alignment list is passed entirely
primers['Multiplex_core']['fp_deg'] = np.vectorize(get_primer, excluded=[0]) \
                                     (alns, primers['Multiplex_core']['AlnID'],
                                      primers['Multiplex_core']['ForwardPrimer(Fp)'])
primers['Multiplex_core']['rp_deg'] = np.vectorize(get_primer, excluded=[0]) \
                                     (alns, primers['Multiplex_core']['AlnID'],
                                      primers['Multiplex_core']['ReversePrimer(Rp)'], reverse=True)
primers['Multiplex_core']
# Out:
#     ID TemplateID          ForwardPrimer(Fp)          ReversePrimer(Rp)  \
# 0    1   531_cons    acattagtgctttattacgtggt     catttctttggcactttctgat
# 1    2   432_cons     acctgcattcgtatgtgttcta     ttcgaggtgggagattttcttc
# 2    3    473_var     tgctatggtacctaaacctacg       cgatgggtcaaacggaatcg
# 3    4    193_var     gccatgacgatatctacaatgc     gcgaacgctgattctaattttg
# 4    2    126_var       ttcaggagctcaccaaatcg     tccttcacctgttgtactgtat
# 5    3    416_var     aactggcactagtcatgtacat     caattaattccgttagcccgtg
# 6    4    495_var      ttcctcgcacactcatgtaag       tctcgatgtagaactgcacg
# 7    5    435_var     agttctttggagagttcggaat     aagaaaagaagtgagaaagcga
# 8    6    283_var    cacacaacttttatgtttaatca      aaaataatggccactattccc
# 9   10   205_cons      agacacaaggccttgaagaag     acagcttcttcttgtcatcgta
# 10   8      579_X         cacctgacactcgatggg         catgcagccggctacttg
# 11  10      575_X      agactttcaggccatgatacc     tcagtgaacgttgacttggtaa
# 12  17      576_X     aggagatgcaagttactatcgc       cactatcgtagcccaggttc
# 13  18      582_X         gaggcgcaggacacgatc      ctcctggatcttctgcatctc
# 14  22      587_X     tttcagcagaaacatccacatg     gtttcgatgtacttggtggttt
# 15   1  474_other    tgaattatgattaatggtgtgcc       caagtgggtgtgacattcca
# 16   3  433_other     aatgcttccattaactgccatt   ggttaagttttaatgtgcgtaaca
# 17   4  298_other  tagaattacaatcaagtggaagacg      ttatacagtggatggcagtcg
# 18   5  356_other     tctatcaccatgcacttcttgt     aatgtagataggctaaaaccgc
# 19   6  439_other     gcgcgtaatcgttttatcaaga    acaaatctgattacgatatgatc
# 20   7  269_other     aatgattcggatgatttgcttc     ccgtcattatttcccaatcaaa
# 21   9  140_other   gtgaattagattttaatgaagtaa  agtgggcagatttaattttagatct
# 22  10  245_other     cgcaattgtcacaaatctgtat       gcagtttacggcttttctcc
# 23  12   65_other       gcaaaatttccgtcccatta      tgtaattagctgtgtcttgtg
#
#     FpTm(Celsius degree)  RpTm(Celsius degree)  FpGC(%)  RpGC(%)  FpPos  \
# 0                  56.87                 56.10    34.78    36.36     18
# 1                  58.12                 58.65    40.91    45.46      5
# 2                  57.66                 59.91    45.46    55.00     46
# 3                  57.98                 57.58    45.46    40.91     16
# 4                  58.48                 57.08    50.00    40.91    123
# 5                  57.77                 58.63    40.91    45.46     19
# 6                  58.62                 58.02    47.62    50.00     68
# 7                  57.97                 56.82    40.91    36.36     48
# 8                  52.53                 54.45    26.09    38.10     53
# 9                  58.73                 58.07    47.62    40.91     41
# 10                 57.65                 59.46    61.11    61.11      0
# 11                 58.03                 58.46    47.62    40.91     11
# 12                 58.60                 58.06    45.46    55.00     24
# 13                 61.14                 58.19    66.67    52.38     24
# 14                 58.08                 57.76    40.91    40.91      6
# 15                 55.92                 58.61    34.78    50.00     13
# 16                 57.50                 57.05    36.36    33.33     23
# 17                 57.76                 58.13    36.00    47.62     52
# 18                 58.04                 56.89    40.91    40.91     40
# 19                 58.39                 52.88    40.91    30.44     47
# 20                 56.06                 55.63    36.36    36.36     12
# 21                 50.09                 57.16    20.83    32.00      2
# 22                 56.29                 57.95    36.36    50.00      8
# 23                 55.11                 54.46    40.00    38.10      4
#
#     RpPos  Penalty  AmpSize(bp) SNPs in primer?  AlnID  \
# 0     207     1.90          190            None    531
# 1     217     0.65          213            None    432
# 2     269     3.91          224            None    473
# 3     249     0.42          234            None    193
# 4     314     0.92          192        low freq    126
# 5     212     0.63          194        low freq    416
# 6     261     2.02          194        low freq    495
# 7     242     1.18          195        low freq    435
# 8     249     4.55          197        low freq    283
# 9     275     0.07          235        low freq    205
# 10    191     5.46          192       high freq    579
# 11    202     0.46          192       high freq    575
# 12    221     2.06          198       high freq    576
# 13    224     1.19          201       high freq    582
# 14    208     0.24          203       high freq    587
# 15    202     2.61          190            None    474
# 16    212     2.95          190            None    433
# 17    241     1.13          190            None    298
# 18    239     1.11          200            None    356
# 19    247     6.12          201            None    439
# 20    214     2.37          203            None    269
# 21    217     3.84          216            None    140
# 22    230     2.05          223            None    245
# 23    235     4.54          232            None     65
#
#                             fp_deg  \
# 0          ACATTAGTGCTTTATTACGTGGT
# 1           ACCTGCATTCGTATGTGTTCTA
# 2           TGCTATGGTACCTAAACCTACG
# 3           GCCATGACGATATCTACAATGC
# 4             TTCAGGAGCTCACCAAATCG
# 5           AACTgGCACTAGTCATGTACAT
# 6            TTCCTCGCACACTCATGTAAG
# 7           AGTTCTTTGGAGAGTTCgGAAT
# 8         CAC-ACAACTTTTATGTTTAATCA
# 9            AGACACAAGGCCTTGAAGAAG
# 10  [C/T]ACCTGACA[C/T]TCGAT[G/C]GG
# 11   aGA[C/T]TTTCAGGCCATGAT[A/C]CC
# 12      AGGA[G/A]ATGCAAGTTACTATcGC
# 13        GAGGC[G/A/T]CAGGACACgATc
# 14          TTtCAGCAGAAACATCCACATG
# 15         TGAATTATGATTAATGGTGTGCC
# 16          AATGCTTCCATTAACTGCCATT
# 17       TAGAATTACAATCAAGTGGAAGACG
# 18          TCTATCACCATGCACTTCTTGT
# 19          GCGCGTAATCGTTTTATCAAGA
# 20          AATGATTCGGATGATTTGCTTC
# 21        GTGAATTAGATTTTAATGAAGTAA
# 22       ---CGCAATTGTCACAAATCTGTAT
# 23            GCAAAATTTCCGTCCCATTA
#
#                                                rp_deg
# 0                              CATTTCTTTGGCACTTTCTGAT
# 1                              TTCGAGGTGGGAGATTTTCTTC
# 2                                CGATGGGTCAAACGGAATCG
# 3                              GCGAACGCTGATTCTAATTTTG
# 4                              TCCTTCACCTGTTGTACTGTAT
# 5                              CAATTAATTCCGTTAGCCCGTG
# 6                                TCTCGATGTAGAACTGCACg
# 7                              AAGAAAAGAAGTGAGAAAGCGA
# 8                               AAAaTAATGGCCACTATTCCC
# 9                              ACAGCTTCTTCTTGTCaTCGTA
# 10  [C/-][A/C/-][T/-/C][G/-/C][C/-/T]AGCCGGCTA[C/T...
# 11             TC[A/C/T/G]GTGAA[C/G]GTTGA[C/T]TTgGTAA
# 12                       C[A/G]CTATCGTAGCCCAG[G/A]TTC
# 13                              cTCCTGGATCTTCTGCATCTC
# 14                         GT[T/C]TCGATGTACTTGGTGGTTT
# 15                               CAAGTGGGTGTGACATTCCA
# 16                           GGTTAAGTTTTAATGTGCGTAACA
# 17                              TTATACAGTGGATGGCAGTCG
# 18                             AATGTAGATAGGCTAAAACCGC
# 19                            ACAAATCTGATTACGATATGATC
# 20                             CCGTCATTATTTCCCAATCAAA
# 21                          AGTGGGCAGATTTAATTTTAGATCT
# 22                               GCAGTTTACGGCTTTTCTCC
# 23                              TGTAATTAGCTGTGTCTTGTG

# %%
primers['Additional markers to add']
primers['Additional markers to add']['AlnID'] = primers['Additional markers to add']['TemplateID'] \
                                        .str.split('_').apply(lambda x: int(x[0]))
# vectorize primer search, excluded - alignment list is passed entirely
primers['Additional markers to add']['fp_deg'] = np.vectorize(get_primer, excluded=[0]) \
                                     (alns, primers['Additional markers to add']['AlnID'],
                                      primers['Additional markers to add']['ForwardPrimer(Fp)'])
primers['Additional markers to add']['rp_deg'] = np.vectorize(get_primer, excluded=[0]) \
                                     (alns, primers['Additional markers to add']['AlnID'],
                                      primers['Additional markers to add']['ReversePrimer(Rp)'], reverse=True)
primers['Additional markers to add']
# Out:
#     ID TemplateID            ForwardPrimer(Fp)             ReversePrimer(Rp)  \
# 0    2     77_var           gtctcggagcacatcgtg     tcgtacttcattattctttggactg
# 1    3     83_var          agtgactccagacggtgtt        ccaaggatttgctactaccact
# 2    4    174_var       gtctcgaaaccgtacgtactaa         cactactactggcctcggata
# 3    5    206_var       agacatatcaaccacaagcgta        acgaagctctgatatgtatcgt
# 4    6     31_var       tgtgtacggtctgaagaacatc         ttatccggctccaagttaagg
# 5    7   281_cons       ccttgtgaacactgttgaactt        agctgtttgaatcgaaaccttc
# 6    9    220_var       ggtcgtaaccaaatgtccaaag        gagtgcactgaaaacctatgtg
# 7   11   418_cons       tgttacggttaccaaatatgct        ggattcttttcagaagacgctc
# 8   12   264_cons          cagatcctccgccttgatg        tccaagggtacgattgaaatca
# 9   13   112_cons         gtatgtagcggggtccattg        gtgctatcgttaagaggtcgta
# 10  14   382_cons       acaagagcaagtactgggagta          atcagctcggtgaacttctc
# 11  15    345_var      gtgttttgtcgaatcatttcaca        cagctgattgtactctgtgagt
# 12  16    317_var        catgttccacaaggaggaaag        atagaacgagtagatatcgcgg
# 13  19   117_cons       ttagcttgctcgatctgatctt        atacttagcaggaccttcatcg
# 14  20   238_cons         atgggtgtgaacatggagac         catgtcggtaaggatgaccag
# 15  21    500_var       cccgctaatgaaaagtaatggt        ccaacaaacggtgcaatatttg
# 16  23    87_cons       tcaaccaggacaagaagaacat         cagatcagcgagatgaccttc
# 17  24   177_cons       gccttaggggatattcaactgt        aatacactttaacgtaaggcgc
# 18  25   214_cons       gttgagaacaacgaagacaacc          atcagatcgacgacaccctt
# 19  26   293_cons         aagtgatcggacggtatgtg        actcattcctttaagctagcgt
# 20  27   449_cons       tgtatgaatccttccttgtggt        tttgggaagttcctatggtgat
# 21  30     99_var       gcgttgttcgttgtagttctac        cgggatatggaagatcacaact
# 22  31    128_var       atttcattgcctgtgccatatc        caaaatgtctaccgtcgacaag
# 23  32    325_var      ccgggaaatgaatttatcgaaga        cgagttgacccattttgtgaat
# 24  34     1_cons       aaggtggaatcacagcatatga        gcgggaagataaggaacgattt
# 25  35    516_var       tttggcgtctgatagaacatct        agctccacggacagtctatata
# 26  36   508_cons        cttcatgaacagacggttgtg         atggtgcagtgtatcatcgag
# 27  38   200_cons        gttccctcgaagcatactttg        gctacgttgctaccactagtaa
# 28  39   277_cons           cagcacgttggagagtcc        gtgcaacttccgtgtaatagtc
# 29  40    72_cons          gaacttctccttcgcgtcc        tatactggttcacggttgagtt
# ..  ..        ...                          ...                           ...
# 39  55   337_cons          gacctgcatcctgtacgtg          cacttgaccttactccagcc
# 40   1  399_other    aaaagtttcaaaattaatcattcag        agtgcaagacagatggctgaaa
# 41   2   33_other           gagcgtgcggccaagatg           acagaccgacgttaatggc
# 42   3  442_other     tcaatttgtcatctttgtttacca        attgacatcaatcgatcgttca
# 43   4  253_other     taaaatgattgcacacctgctcgc            aatcgcgtcggacttgtg
# 44   6  567_other       aatacgctcgcctatagaatgt        aatgcaaattatgtgcgtcgta
# 45   9   81_other           cgctgccagataccgtgc           ctaccaacaccgtctggag
# 46  10   47_other   gatataaattgtcgatcacacaaact      tgcatttatcgtagtacaatctca
# 47  11  568_other    gattttattacaattttccttatga  accagaaattaaaatatgttacacttga
# 48  14   59_other       gctggcgcataattatcacaaa           tttccacttcatcgctcgc
# 49  15  159_other  gacattttaattgatttactgtgtctc        ccatccatttcaatcaacgtca
# 50  16  583_other       tgataatgaacggtgtgaatcg   gtgtcatttaactcaattgtaacttca
# 51  19  355_other      acattgttggtaattaatgtcca      gctgtttatttgtgtatgcaaaca
# 52  21   44_other       cagtcaaatttccagacaatct        cggaagtgcatttgaaggaaaa
# 53  22  469_other          tgaaagcgtgcccaatttg       agtagctcattaatacaatcgct
# 54  23  182_other           gcgtactacgacatccgg          tagatgccctgcttgtagtt
# 55  25  167_other           tccagctcctcgatgctc          aagcagcagaacaacgagat
# 56  27  395_other       aaagttgatgaaaacgcgatga        tttgcgctctatttctgtcgat
# 57  28  485_other       ttgaagatttattagaaatggg        cgaaagtatcaatcactgtcat
# 58  29  280_other       cagaaatgactagaagcagtgc        acattacaatggaagtgatggc
# 59  30  413_other           caaatggcggtcgttgtt           ccgagggtgacacactttt
# 60  31  306_other        ataaaagcttcctcgacagct   tcatgtttataacaaattagtcaagct
# 61  32  526_other     taatttattaattggcgcaaagca          atgatgaatggaaccgcaca
# 62  33  268_other       gcgaccacccacaaattaatta        gtgaagcaaatcatccgaatca
# 63  36  297_other       accatgatgtgctaatctgctt          gcggtgattttattgatccc
# 64  39  555_other           cagctcagcaaggccaac           caacctcgagctgcagatc
# 65  40  586_other          aagacagctccaatcaaca        caaagtcatggcccattaataa
# 66  43  252_other          gctcgtactcggccagtat        tcgatcgtatcctgaaactgtt
# 67  45  249_other           gtaggcccatcgcaccgg        gatcgagagctacatcgagaag
# 68  48  164_other         gatgccaaaattctgaacga         tcaaccacttcgacaagaacc
#
#     FpTm(Celsius degree)  RpTm(Celsius degree)  FpGC(%)  RpGC(%)  FpPos  \
# 0                  58.47                 57.76    61.11    36.00      9
# 1                  58.76                 58.37    52.63    45.46     11
# 2                  58.25                 58.73    45.46    52.38     39
# 3                  58.12                 57.48    40.91    40.91     14
# 4                  58.67                 58.04    45.46    47.62      5
# 5                  57.88                 58.09    40.91    40.91     19
# 6                  58.42                 58.17    45.46    45.46     14
# 7                  56.40                 57.98    36.36    45.46      2
# 8                  58.27                 58.03    57.90    40.91     23
# 9                  58.70                 58.04    55.00    45.46      9
# 10                 59.09                 57.91    45.46    50.00      4
# 11                 57.13                 58.40    34.78    45.46      2
# 12                 57.38                 57.72    47.62    45.46     17
# 13                 57.93                 58.00    40.91    45.46    109
# 14                 58.09                 58.75    50.00    52.38     30
# 15                 57.34                 57.93    40.91    40.91      1
# 16                 58.16                 58.83    40.91    52.38     10
# 17                 58.16                 57.99    45.46    40.91     87
# 18                 58.64                 59.11    45.46    50.00      0
# 19                 58.00                 58.12    50.00    40.91     24
# 20                 57.67                 57.66    40.91    40.91     18
# 21                 58.53                 58.25    45.46    45.46     37
# 22                 57.99                 58.26    40.91    45.46     19
# 23                 57.58                 58.08    39.13    40.91      0
# 24                 58.09                 59.38    40.91    45.46     55
# 25                 58.12                 58.23    40.91    45.46     18
# 26                 58.04                 58.48    47.62    47.62     21
# 27                 57.55                 58.22    47.62    45.46     81
# 28                 58.29                 57.99    61.11    45.46      2
# 29                 58.82                 57.72    57.90    40.91     92
# ..                   ...                   ...      ...      ...    ...
# 39                 58.52                 58.48    57.90    55.00     32
# 40                 52.42                 61.08    20.00    45.46      5
# 41                 62.43                 58.44    66.67    52.63     39
# 42                 56.06                 56.84    29.17    36.36     16
# 43                 63.26                 58.70    45.83    55.56     26
# 44                 57.80                 57.97    40.91    36.36     49
# 45                 61.82                 57.76    66.67    57.90     21
# 46                 57.02                 56.63    30.77    33.33     17
# 47                 51.01                 57.05    20.00    25.00      7
# 48                 58.62                 59.11    40.91    52.63     20
# 49                 56.45                 57.88    29.63    40.91     21
# 50                 57.46                 57.65    40.91    29.63     19
# 51                 55.10                 57.82    30.44    33.33     11
# 52                 55.23                 58.61    36.36    40.91      4
# 53                 57.99                 56.23    47.37    34.78     10
# 54                 57.95                 56.82    61.11    45.00     26
# 55                 59.04                 58.40    61.11    45.00     12
# 56                 58.10                 59.06    36.36    40.91      5
# 57                 50.45                 54.90    27.27    36.36     14
# 58                 57.98                 57.60    45.46    40.91     53
# 59                 57.21                 58.18    50.00    52.63     12
# 60                 57.97                 56.74    42.86    25.93      6
# 61                 57.13                 58.46    29.17    45.00     18
# 62                 57.88                 57.96    40.91    40.91      1
# 63                 58.70                 55.38    40.91    45.00     13
# 64                 59.61                 58.89    61.11    57.90     10
# 65                 54.85                 55.33    42.11    36.36      2
# 66                 59.54                 57.87    57.90    40.91     34
# 67                 63.48                 58.51    72.22    50.00     46
# 68                 55.16                 59.02    40.00    47.62     10
#
#     RpPos  Penalty  AmpSize(bp) SNPs in primer?  AlnID  \
# 0     198     3.24          190       high freq     77
# 1     200     0.37          190       high freq     83
# 2     228     1.73          190       high freq    174
# 3     204     0.52          191       high freq    206
# 4     195     1.04          191       high freq     31
# 5     209     0.09          191       high freq    281
# 6     205     0.17          192       high freq    220
# 7     193     0.02          192       high freq    418
# 8     214     0.03          192       high freq    264
# 9     201     0.03          193       high freq    112
# 10    199     2.09          196       high freq    382
# 11    198     0.40          197       high freq    345
# 12    214     0.28          198       high freq    317
# 13    309     0.00          201       high freq    117
# 14    230     1.75          201       high freq    238
# 15    203     0.07          203       high freq    500
# 16    214     1.83          205       high freq     87
# 17    291     0.02          205       high freq    177
# 18    205     3.11          206       high freq    214
# 19    232     0.12          209       high freq    293
# 20    228     0.34          211       high freq    449
# 21    250     0.25          214       high freq     99
# 22    232     0.26          214       high freq    128
# 23    214     0.08          215       high freq    325
# 24    271     1.38          217       high freq      1
# 25    234     0.23          217       high freq    516
# 26    239     1.48          219       high freq    508
# 27    303     0.22          223       high freq    200
# 28    227     0.01          226       high freq    277
# 29    318     0.29          227       high freq     72
# ..    ...      ...          ...             ...    ...
# 39    280     2.48          249       high freq    337
# 40    194     3.08          190        low freq    399
# 41    228     3.44          190        low freq     33
# 42    205     1.16          190        low freq    442
# 43    215     4.70          190        low freq    253
# 44    238     0.03          190        low freq    567
# 45    210     3.24          190        low freq     81
# 46    207     3.37          191        low freq     47
# 47    197     6.95          191        low freq    568
# 48    211     4.11          192        low freq     59
# 49    213     0.12          193        low freq    159
# 50    211     5.35          193        low freq    583
# 51    205     2.18          195        low freq    355
# 52    198     0.61          195        low freq     44
# 53    205     2.77          196        low freq    469
# 54    222     3.18          197        low freq    182
# 55    208     2.40          197        low freq    167
# 56    204     1.06          200        low freq    395
# 57    213     3.10          200        low freq    485
# 58    253     0.40          201        low freq    280
# 59    212     3.18          201        low freq    413
# 60    207     6.26          202        low freq    306
# 61    222     2.46          205        low freq    526
# 62    211     0.04          211        low freq    268
# 63    227     4.63          215        low freq    297
# 64    229     3.89          220        low freq    555
# 65    222     2.67          221        low freq    586
# 66    258     0.13          225        low freq    252
# 67    278     0.51          233        low freq    249
# 68    259     2.02          250        low freq    164
#
#                                        fp_deg  \
# 0                      GTcTCgGAGCACAT[C/T]GTG
# 1                     AGTG[A/G]CTCCAGACGGTgTT
# 2              GTCTCGAAACCGTA[C/A]GT[A/G]CTAA
# 3        AGACATATC[-/A]AA[C/A]-C[A/-]CAAGCGTA
# 4                  TGT[G/C]TACGGTCTGAAGAACATc
# 5                      CCTTGTGAACACTGTTGAACTT
# 6              gGT[C/T]GTAACCAA[A/G]TGTCCAAAG
# 7              TGTTACG[G/A]TT[A/G]CCAAAtATgCT
# 8         CAGATC[C/T/G]TC[C/T/G]G[C/G]CTTGATg
# 9              G[T/A]ATGTAGCG[G/A/T]GGTCCATTG
# 10                     ACAAGAGCAAGTAcTGGGAGTa
# 11                  GTg--TTTTGTCGAATCATTTCAcA
# 12                      cATGTTCCAcAAGGAGGAAAG
# 13             TTAG[C/T][T/C]TGCTCGATcTGATCTT
# 14                       ATGGGTGTGAACATGGAGAC
# 15         [C/-][C/T]CGcTAATGAAAAGTAATGG[T/A]
# 16                     TCAACCAGGACAAGAAGAACAT
# 17             GCCTTAGG[G/T]GATAT[T/A]CAACTGT
# 18                 GTtGAGAACAACGA[A/G]GACAACC
# 19                   AAGTG[A/G]TCgGACGGTATGTG
# 20                 TGTATGAAtCC[T/C]TCCTTGTGGT
# 21                 GCGT[T/C]GTTCGTTGTAGTTCTAC
# 22                     ATTTCATtGCCTGTGCCATATC
# 23  CC[G/C/T]GG[A/C]AATGA[A/G]TT[T/C]ATCGAAGA
# 24                     AAGGTGGAATCACAGCATATGA
# 25                 TTTGGCGTCTG[A/G]TAGAACATCT
# 26                      CTTCATgAACAGACGGTTGTG
# 27            GTTC[C/A/T]CTCGAAGC[A/C]TACTTTG
# 28                     CAGCACGTT[G/C]GAgAGTCC
# 29                    GAACTTCTCCTTCGC[G/A]TCC
# ..                                        ...
# 39                    GAC[C/G]TGCATcCTGTACGTG
# 40                  AAAAGTTTCAAAATTAATCATTCAG
# 41                         GAGCGtGCGGCcAAGATG
# 42                   TCAATTTGTCaTCTTTGTTTACCA
# 43                   TAAAATGATTGCACACCTGcTCGC
# 44                     AATACGCTCGCCTATAGAATGT
# 45                         CGCTGCCAGATaCCGTGC
# 46                 GaTATAAATTGTCGATCACACAAACT
# 47                  GATTTTATTACAaTTTTCCTTATGA
# 48                     GCTGGCGCATAATTATCaCAAA
# 49                GACATTTTAATTGATtTACTGTGTCTC
# 50                     TGATAATGAaCGGTGTGAATCG
# 51                    ACATTGTTGGTAATTAATGTcCA
# 52                     CAGTCAAATTTCCAGACAATCT
# 53                        TGAAAGCGTGCCCAATTTG
# 54                         GCGTACTACGACATCCGg
# 55                         TCCAGCTCcTCGATGCTC
# 56                     AAAGTTGATGAAAACGCGATGA
# 57                     TtGAAGATTTATTAGAAATGGG
# 58                     CAGAAATGACTAGAAGCAGTGC
# 59                         CAAATGGCGGtCGTTGTT
# 60                      ATAAAAGCTTCcTCGACAGCT
# 61                   tAATTTATTAATTGGcGCAaAGCA
# 62                     GCGACCACCCACAAATTAATTA
# 63                     aCCATGATGTGCTAATCTGCTT
# 64                         CAGCTCAGCAAGGCCAAC
# 65                        AaGACAGCTCCAATCAACA
# 66                        GCTCGTACTCGGccAGTAT
# 67                         GTAGGCCCATCGCACCGG
# 68                       GATGCCAAAATTCTGAAcGA
#
#                                           rp_deg
# 0                      TCGTACTTCATTATTCTTTGGACTG
# 1                   CC[A/T/G]AGGATTTGCTACTACCAcT
# 2                      CACTAcTACTGGCC[T/C]CGGATA
# 3   a[C/T][G/T][A/T/G][A/G]GCTCTGATATGt[A/G]TCGT
# 4                      TT[A/G]TCCGGCTCCAAGTTAAGG
# 5                 AgCTGTT[T/C]GAATCGAAACC[T/A]TC
# 6                         GAGTGCACTGAAAACCTATGTG
# 7                     GGATTCTTTTCAGAaGACG[C/T]TC
# 8                     TC[C/G]AAGGGTACgATTGAAATCA
# 9                         GTGCTATCGTTAAGAGGTCGTA
# 10                    ATCAGCTC[G/A/C]GTGAACTTCTC
# 11                  CAGCTGATTGT[A/C/G]CTCTGTGAGT
# 12            [A/G]TAGAACGAGTAgAT[A/G]TCGCG[G/A]
# 13                  ATACTTAGCAGGACCTTCAT[C/A/T]G
# 14               CATGTCGGT[A/C/G]AGgATGAC[C/G]AG
# 15              CCAACAAACGG[T/G][G/A/C]CAATATTTG
# 16           CA[G/A]ATCAGCGAGAT[G/A/C]ACCTT[C/G]
# 17                    [A/G]ATACACTTTAACGTAAGGCGC
# 18                      ATCAGATCGAC[G/A]ACACCcTT
# 19                    ACTCATTCCTTTAA[G/A]CTAGCgT
# 20                TTTGGGA[A/G]GT[T/G]CCTATGGTGAT
# 21        CG[G/C]GA[T/C]ATGGAAGA[T/C]CACAA[C/T]T
# 22                    CAA[A/C]ATGTCTACCGTCGACAAG
# 23                CGA[G/A]TTGACCCA[T/C]TTTGTGAAT
# 24        [G/A]CGGGAAGA[T/C]AA[G/A]GA[A/G]CGATTT
# 25                AGCT[C/T]CACGGACAGTCTAT[A/C]TA
# 26                     ATGGTGCAGTGTATCAT[C/T]GAg
# 27                GCTAC[G/A]TTgCTACC[A/G]CTAGTAA
# 28                    GTGCAACTTC[C/T]GTGTAATAGTC
# 29              T[A/C/G]TACTGGTTCACGGT[T/C]GAGTT
# ..                                           ...
# 39                          CACTTGACCTTACTCCAGCC
# 40                       AG-TGCAAGACAGATgGCtGAAA
# 41                           ACAgACCGACGTTAATGGC
# 42                        ATTGACATCAATCGATCGTTCA
# 43                            AATCGcGTcGGACTTGTG
# 44                        AATGCAAATTATGTgcgTCGTA
# 45                           CTACCAAcACCGTCTGGAG
# 46                      TGCATTTATCGTAGTACAATCTCA
# 47                  ACCAGAAATTAAAATATGTTAcACTTGA
# 48                           tTTCCACTTCATCGCTCGC
# 49                        CCATCCATTTCAATCAACGTCA
# 50                   GTGTCATTTAACTCAATTGTAACTTCA
# 51                      GCTGTtTATTTGTGTATGCAAACA
# 52                       CGGAAGTGCATTTGAAGG-AAaA
# 53                       AgTAGCTCATTAAtACAATCGCt
# 54                          TAGATGCCCTGCTTGTAGTT
# 55                          AAGCAGCAGAACAAcGAgAT
# 56                        TTTGCGCTCTATTTCTGTCGAT
# 57                        cGAAaGTATCAATCACTGTCAT
# 58                        ACATTACAATGGAAGTGAtGGC
# 59                           CCGAGGGTGACACACTTTT
# 60                   TCATGTTTATAACAAATTAGTCAAGCT
# 61                          ATGATGAATGGAACCGCACA
# 62                        GtGAAGCAAATCATCCGAATCA
# 63                          GcGGTGATTTTATTGATCCC
# 64                           CaACcTCgAGCTGCAGATC
# 65                        cAAAGTCATGGCCCATTAATAA
# 66                        TCGATCGTATCCTGAAACTGTT
# 67                        GATCGAgAGCTACATCGAGAAG
# 68                         TCAACCACTTCGACAAGAACC
#
# [69 rows x 16 columns]

# %%
writer = pd.ExcelWriter(OUT_FILE)
for (k,v) in primers.items():
    v.to_excel(writer, sheet_name=k)
writer.save()
